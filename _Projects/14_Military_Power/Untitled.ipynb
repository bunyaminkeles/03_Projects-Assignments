# %%
#!pip install pyforest

# 1-Import Libraies
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.formula.api as smf
import missingno as msno 

from sklearn.compose import make_column_transformer

#Scaling
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler


#Importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

#Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

#Figure&Display options
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#!pip install termcolor
import colorama
from colorama import Fore, Style  # maakes strings colored
from termcolor import colored

from scipy.cluster.hierarchy import dendrogram, linkage
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df0 = pd.read_csv("World military power.csv", header=1)

# %%
df = df0.copy()

# %%
## Useful Functions

###############################################################################

def missing(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

def missing_values(df):
    return missing(df)[missing(df)['Missing_Number']>0]

###############################################################################

def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          f"There is ", df.shape[0], " observation and ", df.shape[1], " columns in the dataset.", '\n',
          colored('-'*79, 'red', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

    print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')

def duplicate_values(df):
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored("duplicates were dropped", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
    else:
        print(colored("No duplicates", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('We will now check the missing values and if necessary drop some columns!!!', attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_null(df, limit):
    print('Shape:', df.shape)
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'null and were dropped')
            df.drop(i, axis=1, inplace=True)
            print('new shape:', df.shape)
        else:
            print(df.isnull().sum()[i], '%, percentage of missing values of', i ,'less than limit', limit, '%, so we will keep it.')
    print('New shape after missing value control:', df.shape)

###############################################################################

# %%
df.head(2)
# Out:
#   Military Strength  Military Strength Power Index Aircraft Strength  \
# 0       Afghanistan                          1.344       Afghanistan
# 1           Albania                          2.314           Albania
#
#   Aircraft Strength value Fighter/Interceptor Strength  \
# 0                     260                  Afghanistan
# 1                      19                      Albania
#
#   Fighter/Interceptor Strength value Attack Aircraft Strength  \
# 0                                  0              Afghanistan
# 1                                  0                  Albania
#
#    Attack Aircraft Strength value Transport Aircraft Fleet Strength  \
# 0                          25.000                       Afghanistan
# 1                           0.000                           Albania
#
#    Transport Aircraft Fleet Strength value Trainer Aircraft Fleet  \
# 0                                   30.000            Afghanistan
# 1                                    0.000                Albania
#
#   Trainer Aircraft Fleet value Helicopter Fleet Strength  \
# 0                            0               Afghanistan
# 1                            0                   Albania
#
#   Helicopter Fleet Strength value Attack Helicopter Fleet Strength  \
# 0                             187                      Afghanistan
# 1                              19                          Albania
#
#    Attack Helicopter Fleet Strength value Tank Strength Tank Strength value  \
# 0                                   0.000   Afghanistan                   0
# 1                                   0.000       Albania                   0
#
#   AFV/APC Strength AFV/APC Strength value Self-Propelled Artillery Strength  \
# 0      Afghanistan                  1,062                       Afghanistan
# 1          Albania                    467                           Albania
#
#   Self-Propelled Artillery Strength value Towed Artillery Strength  \
# 0                                       0              Afghanistan
# 1                                       0                  Albania
#
#   Towed Artillery Strength value Rocket Projector Strength  \
# 0                            176               Afghanistan
# 1                              0                   Albania
#
#   Rocket Projector Strength value Navy Fleet Strengths  \
# 0                              50          Afghanistan
# 1                               0              Albania
#
#    Navy Fleet Strengths value Aircraft Carrier Fleet Strength  \
# 0                       0.000                     Afghanistan
# 1                      38.000                         Albania
#
#    Aircraft Carrier Fleet Strength value Submarine Fleet Strength  \
# 0                                  0.000              Afghanistan
# 1                                  0.000                  Albania
#
#    Submarine Fleet Strength value Destroyer Fleet Strength  \
# 0                           0.000              Afghanistan
# 1                           0.000                  Albania
#
#    Destroyer Fleet Strength value Frigate Fleet Strength  \
# 0                           0.000            Afghanistan
# 1                           0.000                Albania
#
#    Frigate Fleet Strength value defense spending budget  \
# 0                         0.000             Afghanistan
# 1                         0.000                 Albania
#
#   defense spending budget value External Debt External Debt value  \
# 0               12,00,00,00,000   Afghanistan      2,84,00,00,000
# 1                  25,00,00,000       Albania      9,50,50,00,000
#
#   Airport Totals Airport Totals value Oil Production Oil Production value  \
# 0    Afghanistan                   43    Afghanistan                    0
# 1        Albania                    4        Albania               16,000
#
#   Oil Consumption Oil Consumption value Proven Oil Reserves  \
# 0     Afghanistan                 5,500         Afghanistan
# 1         Albania                42,500             Albania
#
#   Proven Oil Reserves value Available Manpower Available Manpower value  \
# 0                         0        Afghanistan              1,43,25,743
# 1              16,83,00,000            Albania                15,19,438
#
#   Total Population Total Population value Total Square Land Area  \
# 0      Afghanistan            3,49,40,837            Afghanistan
# 1          Albania              30,57,220                Albania
#
#   Total Square Land Area value Total Coastline Coverage  \
# 0                     6,52,230              Afghanistan
# 1                       28,748                  Albania
#
#   Total Coastline Coverage value Total Waterway Coverage  \
# 0                              0             Afghanistan
# 1                            362                 Albania
#
#   Total Waterway Coverage value Total Border Coverage  \
# 0                         1,200           Afghanistan
# 1                            41               Albania
#
#   Total Border Coverage value
# 0                       5,987
# 1                         691

# %%
first_looking(df)
# Out:
# Shape:(165, 60)
# There is 165 observation and 60 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 60 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Military Strength                        138 non-null    object
#  1   Military Strength Power Index            138 non-null    float64
#  2   Aircraft Strength                        138 non-null    object
#  3   Aircraft Strength value                  138 non-null    object
#  4   Fighter/Interceptor Strength             138 non-null    object
#  5   Fighter/Interceptor Strength value       138 non-null    object
#  6   Attack Aircraft Strength                 138 non-null    object
#  7   Attack Aircraft Strength value           138 non-null    float64
#  8   Transport Aircraft Fleet Strength        138 non-null    object
#  9   Transport Aircraft Fleet Strength value  138 non-null    float64
#  10  Trainer Aircraft Fleet                   138 non-null    object
#  11  Trainer Aircraft Fleet value             138 non-null    object
#  12  Helicopter Fleet Strength                138 non-null    object
#  13  Helicopter Fleet Strength value          138 non-null    object
#  14  Attack Helicopter Fleet Strength         138 non-null    object
#  15  Attack Helicopter Fleet Strength value   138 non-null    float64
#  16  Tank Strength                            138 non-null    object
#  17  Tank Strength value                      138 non-null    object
#  18  AFV/APC Strength                         138 non-null    object
#  19  AFV/APC Strength value                   138 non-null    object
#  20  Self-Propelled Artillery Strength        138 non-null    object
#  21  Self-Propelled Artillery Strength value  138 non-null    object
#  22  Towed Artillery Strength                 138 non-null    object
#  23  Towed Artillery Strength value           138 non-null    object
#  24  Rocket Projector Strength                138 non-null    object
#  25  Rocket Projector Strength value          138 non-null    object
#  26  Navy Fleet Strengths                     124 non-null    object
#  27  Navy Fleet Strengths value               124 non-null    float64
#  28  Aircraft Carrier Fleet Strength          115 non-null    object
#  29  Aircraft Carrier Fleet Strength value    115 non-null    float64
#  30  Submarine Fleet Strength                 115 non-null    object
#  31  Submarine Fleet Strength value           115 non-null    float64
#  32  Destroyer Fleet Strength                 115 non-null    object
#  33  Destroyer Fleet Strength value           115 non-null    float64
#  34  Frigate Fleet Strength                   115 non-null    object
#  35  Frigate Fleet Strength value             115 non-null    float64
#  36  defense spending budget                  138 non-null    object
#  37  defense spending budget value            138 non-null    object
#  38  External Debt                            138 non-null    object
#  39  External Debt value                      138 non-null    object
#  40  Airport Totals                           138 non-null    object
#  41  Airport Totals value                     138 non-null    object
#  42  Oil Production                           138 non-null    object
#  43  Oil Production value                     138 non-null    object
#  44  Oil Consumption                          138 non-null    object
#  45  Oil Consumption value                    138 non-null    object
#  46  Proven Oil Reserves                      138 non-null    object
#  47  Proven Oil Reserves value                138 non-null    object
#  48  Available Manpower                       138 non-null    object
#  49  Available Manpower value                 138 non-null    object
#  50  Total Population                         138 non-null    object
#  51  Total Population value                   138 non-null    object
#  52  Total Square Land Area                   138 non-null    object
#  53  Total Square Land Area value             138 non-null    object
#  54  Total Coastline Coverage                 109 non-null    object
#  55  Total Coastline Coverage value           109 non-null    object
#  56  Total Waterway Coverage                  138 non-null    object
#  57  Total Waterway Coverage value            138 non-null    object
#  58  Total Border Coverage                    129 non-null    object
#  59  Total Border Coverage value              129 non-null    object
# dtypes: float64(9), object(51)
# memory usage: 77.5+ KB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Military Strength                          138
# Military Strength Power Index              138
# Aircraft Strength                          138
# Aircraft Strength value                    113
# Fighter/Interceptor Strength               138
# Fighter/Interceptor Strength value          63
# Attack Aircraft Strength                   138
# Attack Aircraft Strength value              38
# Transport Aircraft Fleet Strength          138
# Transport Aircraft Fleet Strength value     49
# Trainer Aircraft Fleet                     138
# Trainer Aircraft Fleet value                77
# Helicopter Fleet Strength                  138
# Helicopter Fleet Strength value             97
# Attack Helicopter Fleet Strength           138
# Attack Helicopter Fleet Strength value      45
# Tank Strength                              138
# Tank Strength value                        106
# AFV/APC Strength                           138
# AFV/APC Strength value                     130
# Self-Propelled Artillery Strength          138
# Self-Propelled Artillery Strength value     70
# Towed Artillery Strength                   138
# Towed Artillery Strength value              91
# Rocket Projector Strength                  138
# Rocket Projector Strength value             68
# Navy Fleet Strengths                       124
# Navy Fleet Strengths value                  78
# Aircraft Carrier Fleet Strength            115
# Aircraft Carrier Fleet Strength value        5
# Submarine Fleet Strength                   115
# Submarine Fleet Strength value              20
# Destroyer Fleet Strength                   115
# Destroyer Fleet Strength value              11
# Frigate Fleet Strength                     115
# Frigate Fleet Strength value                18
# defense spending budget                    138
# defense spending budget value              124
# External Debt                              138
# External Debt value                        138
# Airport Totals                             138
# Airport Totals value                       108
# Oil Production                             138
# Oil Production value                        88
# Oil Consumption                            138
# Oil Consumption value                      102
# Proven Oil Reserves                        138
# Proven Oil Reserves value                   84
# Available Manpower                         138
# Available Manpower value                   138
# Total Population                           138
# Total Population value                     138
# Total Square Land Area                     138
# Total Square Land Area value               138
# Total Coastline Coverage                   109
# Total Coastline Coverage value             104
# Total Waterway Coverage                    138
# Total Waterway Coverage value               92
# Total Border Coverage                      129
# Total Border Coverage value                125
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#                                          Missing_Number  Missing_Percent
# Total Coastline Coverage value                       56            0.339
# Total Coastline Coverage                             56            0.339
# Submarine Fleet Strength                             50            0.303
# Frigate Fleet Strength value                         50            0.303
# Frigate Fleet Strength                               50            0.303
# Destroyer Fleet Strength value                       50            0.303
# Destroyer Fleet Strength                             50            0.303
# Submarine Fleet Strength value                       50            0.303
# Aircraft Carrier Fleet Strength value                50            0.303
# Aircraft Carrier Fleet Strength                      50            0.303
# Navy Fleet Strengths                                 41            0.248
# Navy Fleet Strengths value                           41            0.248
# Total Border Coverage                                36            0.218
# Total Border Coverage value                          36            0.218
# Attack Helicopter Fleet Strength                     27            0.164
# Available Manpower                                   27            0.164
# External Debt value                                  27            0.164
# Airport Totals                                       27            0.164
# Airport Totals value                                 27            0.164
# Oil Production                                       27            0.164
# Oil Production value                                 27            0.164
# Oil Consumption                                      27            0.164
# Oil Consumption value                                27            0.164
# Proven Oil Reserves                                  27            0.164
# Proven Oil Reserves value                            27            0.164
# Available Manpower value                             27            0.164
# Attack Helicopter Fleet Strength value               27            0.164
# Total Population                                     27            0.164
# Total Population value                               27            0.164
# Total Square Land Area                               27            0.164
# Total Square Land Area value                         27            0.164
# Fighter/Interceptor Strength                         27            0.164
# Aircraft Strength value                              27            0.164
# Total Waterway Coverage                              27            0.164
# Total Waterway Coverage value                        27            0.164
# Aircraft Strength                                    27            0.164
# External Debt                                        27            0.164
# defense spending budget value                        27            0.164
# defense spending budget                              27            0.164
# Fighter/Interceptor Strength value                   27            0.164
# Tank Strength                                        27            0.164
# Tank Strength value                                  27            0.164
# AFV/APC Strength                                     27            0.164
# AFV/APC Strength value                               27            0.164
# Self-Propelled Artillery Strength                    27            0.164
# Self-Propelled Artillery Strength value              27            0.164
# Towed Artillery Strength                             27            0.164
# Towed Artillery Strength value                       27            0.164
# Rocket Projector Strength                            27            0.164
# Rocket Projector Strength value                      27            0.164
# Helicopter Fleet Strength value                      27            0.164
# Helicopter Fleet Strength                            27            0.164
# Trainer Aircraft Fleet value                         27            0.164
# Trainer Aircraft Fleet                               27            0.164
# Military Strength Power Index                        27            0.164
# Transport Aircraft Fleet Strength value              27            0.164
# Transport Aircraft Fleet Strength                    27            0.164
# Attack Aircraft Strength value                       27            0.164
# Attack Aircraft Strength                             27            0.164
# Military Strength                                    27            0.164
# -------------------------------------------------------------------------------
# All Columns:['Military Strength', 'Military Strength Power Index', 'Aircraft Strength', 'Aircraft Strength value', 'Fighter/Interceptor Strength', 'Fighter/Interceptor Strength value', 'Attack Aircraft Strength', 'Attack Aircraft Strength value', 'Transport Aircraft Fleet Strength', 'Transport Aircraft Fleet Strength value', 'Trainer Aircraft Fleet', 'Trainer Aircraft Fleet value', 'Helicopter Fleet Strength', 'Helicopter Fleet Strength value', 'Attack Helicopter Fleet Strength', 'Attack Helicopter Fleet Strength value', 'Tank Strength', 'Tank Strength value', 'AFV/APC Strength', 'AFV/APC Strength value', 'Self-Propelled Artillery Strength', 'Self-Propelled Artillery Strength value', 'Towed Artillery Strength', 'Towed Artillery Strength value', 'Rocket Projector Strength', 'Rocket Projector Strength value', 'Navy Fleet Strengths', 'Navy Fleet Strengths value', 'Aircraft Carrier Fleet Strength', 'Aircraft Carrier Fleet Strength value', 'Submarine Fleet Strength', 'Submarine Fleet Strength value', 'Destroyer Fleet Strength', 'Destroyer Fleet Strength value', 'Frigate Fleet Strength', 'Frigate Fleet Strength value', 'defense spending budget', 'defense spending budget value', 'External Debt', 'External Debt value', 'Airport Totals', 'Airport Totals value', 'Oil Production', 'Oil Production value', 'Oil Consumption', 'Oil Consumption value', 'Proven Oil Reserves', 'Proven Oil Reserves value', 'Available Manpower', 'Available Manpower value', 'Total Population', 'Total Population value', 'Total Square Land Area', 'Total Square Land Area value', 'Total Coastline Coverage', 'Total Coastline Coverage value', 'Total Waterway Coverage', 'Total Waterway Coverage value', 'Total Border Coverage', 'Total Border Coverage value']
# -------------------------------------------------------------------------------
# Columns after rename:['military_strength', 'military_strength_power_index', 'aircraft_strength', 'aircraft_strength_value', 'fighter/interceptor_strength', 'fighter/interceptor_strength_value', 'attack_aircraft_strength', 'attack_aircraft_strength_value', 'transport_aircraft_fleet_strength', 'transport_aircraft_fleet_strength_value', 'trainer_aircraft_fleet', 'trainer_aircraft_fleet_value', 'helicopter_fleet_strength', 'helicopter_fleet_strength_value', 'attack_helicopter_fleet_strength', 'attack_helicopter_fleet_strength_value', 'tank_strength', 'tank_strength_value', 'afv/apc_strength', 'afv/apc_strength_value', 'self-propelled_artillery_strength', 'self-propelled_artillery_strength_value', 'towed_artillery_strength', 'towed_artillery_strength_value', 'rocket_projector_strength', 'rocket_projector_strength_value', 'navy_fleet_strengths', 'navy_fleet_strengths_value', 'aircraft_carrier_fleet_strength', 'aircraft_carrier_fleet_strength_value', 'submarine_fleet_strength', 'submarine_fleet_strength_value', 'destroyer_fleet_strength', 'destroyer_fleet_strength_value', 'frigate_fleet_strength', 'frigate_fleet_strength_value', 'defense_spending_budget', 'defense_spending_budget_value', 'external_debt', 'external_debt_value', 'airport_totals', 'airport_totals_value', 'oil_production', 'oil_production_value', 'oil_consumption', 'oil_consumption_value', 'proven_oil_reserves', 'proven_oil_reserves_value', 'available_manpower', 'available_manpower_value', 'total_population', 'total_population_value', 'total_square_land_area', 'total_square_land_area_value', 'total_coastline_coverage', 'total_coastline_coverage_value', 'total_waterway_coverage', 'total_waterway_coverage_value', 'total_border_coverage', 'total_border_coverage_value']
# -------------------------------------------------------------------------------

# %%
df.tail(2)
# Out:
#     military_strength  military_strength_power_index aircraft_strength  \
# 163               NaN                            NaN               NaN
# 164               NaN                            NaN               NaN
#
#     aircraft_strength_value fighter/interceptor_strength  \
# 163                     NaN                          NaN
# 164                     NaN                          NaN
#
#     fighter/interceptor_strength_value attack_aircraft_strength  \
# 163                                NaN                      NaN
# 164                                NaN                      NaN
#
#      attack_aircraft_strength_value transport_aircraft_fleet_strength  \
# 163                             NaN                               NaN
# 164                             NaN                               NaN
#
#      transport_aircraft_fleet_strength_value trainer_aircraft_fleet  \
# 163                                      NaN                    NaN
# 164                                      NaN                    NaN
#
#     trainer_aircraft_fleet_value helicopter_fleet_strength  \
# 163                          NaN                       NaN
# 164                          NaN                       NaN
#
#     helicopter_fleet_strength_value attack_helicopter_fleet_strength  \
# 163                             NaN                              NaN
# 164                             NaN                              NaN
#
#      attack_helicopter_fleet_strength_value tank_strength tank_strength_value  \
# 163                                     NaN           NaN                 NaN
# 164                                     NaN           NaN                 NaN
#
#     afv/apc_strength afv/apc_strength_value self-propelled_artillery_strength  \
# 163              NaN                    NaN                               NaN
# 164              NaN                    NaN                               NaN
#
#     self-propelled_artillery_strength_value towed_artillery_strength  \
# 163                                     NaN                      NaN
# 164                                     NaN                      NaN
#
#     towed_artillery_strength_value rocket_projector_strength  \
# 163                            NaN                       NaN
# 164                            NaN                       NaN
#
#     rocket_projector_strength_value navy_fleet_strengths  \
# 163                             NaN                  NaN
# 164                             NaN                  NaN
#
#      navy_fleet_strengths_value aircraft_carrier_fleet_strength  \
# 163                         NaN                             NaN
# 164                         NaN                             NaN
#
#      aircraft_carrier_fleet_strength_value submarine_fleet_strength  \
# 163                                    NaN                      NaN
# 164                                    NaN                      NaN
#
#      submarine_fleet_strength_value destroyer_fleet_strength  \
# 163                             NaN                      NaN
# 164                             NaN                      NaN
#
#      destroyer_fleet_strength_value frigate_fleet_strength  \
# 163                             NaN                    NaN
# 164                             NaN                    NaN
#
#      frigate_fleet_strength_value defense_spending_budget  \
# 163                           NaN                     NaN
# 164                           NaN                     NaN
#
#     defense_spending_budget_value external_debt external_debt_value  \
# 163                           NaN           NaN                 NaN
# 164                           NaN           NaN                 NaN
#
#     airport_totals airport_totals_value oil_production oil_production_value  \
# 163            NaN                  NaN            NaN                  NaN
# 164            NaN                  NaN            NaN                  NaN
#
#     oil_consumption oil_consumption_value proven_oil_reserves  \
# 163             NaN                   NaN                 NaN
# 164             NaN                   NaN                 NaN
#
#     proven_oil_reserves_value available_manpower available_manpower_value  \
# 163                       NaN                NaN                      NaN
# 164                       NaN                NaN                      NaN
#
#     total_population total_population_value total_square_land_area  \
# 163              NaN                    NaN                    NaN
# 164              NaN                    NaN                    NaN
#
#     total_square_land_area_value total_coastline_coverage  \
# 163                          NaN                      NaN
# 164                          NaN                      NaN
#
#     total_coastline_coverage_value total_waterway_coverage  \
# 163                            NaN                     NaN
# 164                            NaN                     NaN
#
#     total_waterway_coverage_value total_border_coverage  \
# 163                           NaN                   NaN
# 164                           NaN                   NaN
#
#     total_border_coverage_value
# 163                         NaN
# 164                         NaN

# %%
print("There is", df.shape[0], "observation and", df.shape[1], "columns in the dataset")
# Out:
# There is 165 observation and 60 columns in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 60 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   military_strength                        138 non-null    object
#  1   military_strength_power_index            138 non-null    float64
#  2   aircraft_strength                        138 non-null    object
#  3   aircraft_strength_value                  138 non-null    object
#  4   fighter/interceptor_strength             138 non-null    object
#  5   fighter/interceptor_strength_value       138 non-null    object
#  6   attack_aircraft_strength                 138 non-null    object
#  7   attack_aircraft_strength_value           138 non-null    float64
#  8   transport_aircraft_fleet_strength        138 non-null    object
#  9   transport_aircraft_fleet_strength_value  138 non-null    float64
#  10  trainer_aircraft_fleet                   138 non-null    object
#  11  trainer_aircraft_fleet_value             138 non-null    object
#  12  helicopter_fleet_strength                138 non-null    object
#  13  helicopter_fleet_strength_value          138 non-null    object
#  14  attack_helicopter_fleet_strength         138 non-null    object
#  15  attack_helicopter_fleet_strength_value   138 non-null    float64
#  16  tank_strength                            138 non-null    object
#  17  tank_strength_value                      138 non-null    object
#  18  afv/apc_strength                         138 non-null    object
#  19  afv/apc_strength_value                   138 non-null    object
#  20  self-propelled_artillery_strength        138 non-null    object
#  21  self-propelled_artillery_strength_value  138 non-null    object
#  22  towed_artillery_strength                 138 non-null    object
#  23  towed_artillery_strength_value           138 non-null    object
#  24  rocket_projector_strength                138 non-null    object
#  25  rocket_projector_strength_value          138 non-null    object
#  26  navy_fleet_strengths                     124 non-null    object
#  27  navy_fleet_strengths_value               124 non-null    float64
#  28  aircraft_carrier_fleet_strength          115 non-null    object
#  29  aircraft_carrier_fleet_strength_value    115 non-null    float64
#  30  submarine_fleet_strength                 115 non-null    object
#  31  submarine_fleet_strength_value           115 non-null    float64
#  32  destroyer_fleet_strength                 115 non-null    object
#  33  destroyer_fleet_strength_value           115 non-null    float64
#  34  frigate_fleet_strength                   115 non-null    object
#  35  frigate_fleet_strength_value             115 non-null    float64
#  36  defense_spending_budget                  138 non-null    object
#  37  defense_spending_budget_value            138 non-null    object
#  38  external_debt                            138 non-null    object
#  39  external_debt_value                      138 non-null    object
#  40  airport_totals                           138 non-null    object
#  41  airport_totals_value                     138 non-null    object
#  42  oil_production                           138 non-null    object
#  43  oil_production_value                     138 non-null    object
#  44  oil_consumption                          138 non-null    object
#  45  oil_consumption_value                    138 non-null    object
#  46  proven_oil_reserves                      138 non-null    object
#  47  proven_oil_reserves_value                138 non-null    object
#  48  available_manpower                       138 non-null    object
#  49  available_manpower_value                 138 non-null    object
#  50  total_population                         138 non-null    object
#  51  total_population_value                   138 non-null    object
#  52  total_square_land_area                   138 non-null    object
#  53  total_square_land_area_value             138 non-null    object
#  54  total_coastline_coverage                 109 non-null    object
#  55  total_coastline_coverage_value           109 non-null    object
#  56  total_waterway_coverage                  138 non-null    object
#  57  total_waterway_coverage_value            138 non-null    object
#  58  total_border_coverage                    129 non-null    object
#  59  total_border_coverage_value              129 non-null    object
# dtypes: float64(9), object(51)
# memory usage: 77.5+ KB

# %%
df.describe().T
# Out:
#                                           count   mean     std   min    25%  \
# military_strength_power_index           138.000  1.461   1.324 0.061  0.575
# attack_aircraft_strength_value          138.000 25.761  94.528 0.000  0.000
# transport_aircraft_fleet_strength_value 138.000 30.232  92.330 0.000  3.000
# attack_helicopter_fleet_strength_value  138.000 25.623  97.326 0.000  0.000
# navy_fleet_strengths_value              124.000 84.984 146.114 0.000 10.000
# aircraft_carrier_fleet_strength_value   115.000  0.383   1.972 0.000  0.000
# submarine_fleet_strength_value          115.000  4.800  13.707 0.000  0.000
# destroyer_fleet_strength_value          115.000  2.052  10.001 0.000  0.000
# frigate_fleet_strength_value            115.000  3.522   6.481 0.000  0.000
#
#                                            50%    75%     max
# military_strength_power_index            1.034  2.022  10.168
# attack_aircraft_strength_value           0.000 15.750 742.000
# transport_aircraft_fleet_strength_value  9.000 26.000 945.000
# attack_helicopter_fleet_strength_value   2.000 17.750 967.000
# navy_fleet_strengths_value              38.000 77.750 984.000
# aircraft_carrier_fleet_strength_value    0.000  0.000  20.000
# submarine_fleet_strength_value           0.000  4.000  83.000
# destroyer_fleet_strength_value           0.000  0.000  91.000
# frigate_fleet_strength_value             0.000  5.500  52.000

# %%
df.describe(include=object).T
# Out:
#                                         count unique              top freq
# military_strength                         138    138            Qatar    1
# aircraft_strength                         138    138            Qatar    1
# aircraft_strength_value                   138    113               19    5
# fighter/interceptor_strength              138    138            Qatar    1
# fighter/interceptor_strength_value        138     63                0   46
# attack_aircraft_strength                  138    138            Qatar    1
# transport_aircraft_fleet_strength         138    138            Qatar    1
# trainer_aircraft_fleet                    138    138            Qatar    1
# trainer_aircraft_fleet_value              138     77                0   25
# helicopter_fleet_strength                 138    138            Qatar    1
# helicopter_fleet_strength_value           138     97                8    4
# attack_helicopter_fleet_strength          138    138            Qatar    1
# tank_strength                             138    138            Qatar    1
# tank_strength_value                       138    106                0   24
# afv/apc_strength                          138    138            Qatar    1
# afv/apc_strength_value                    138    130            2,000    4
# self-propelled_artillery_strength         138    138            Qatar    1
# self-propelled_artillery_strength_value   138     70                0   52
# towed_artillery_strength                  138    138            Qatar    1
# towed_artillery_strength_value            138     91                0   24
# rocket_projector_strength                 138    138            Qatar    1
# rocket_projector_strength_value           138     68                0   46
# navy_fleet_strengths                      124    124            Qatar    1
# aircraft_carrier_fleet_strength           115    115            Qatar    1
# submarine_fleet_strength                  115    115            Qatar    1
# destroyer_fleet_strength                  115    115            Qatar    1
# frigate_fleet_strength                    115    115            Qatar    1
# defense_spending_budget                   138    138            Qatar    1
# defense_spending_budget_value             138    124   2,50,00,00,000    3
# external_debt                             138    138            Qatar    1
# external_debt_value                       138    138  16,90,00,00,000    1
# airport_totals                            138    138            Qatar    1
# airport_totals_value                      138    108               29    3
# oil_production                            138    138            Qatar    1
# oil_production_value                      138     88                0   46
# oil_consumption                           138    138            Qatar    1
# oil_consumption_value                     138    102           18,500    4
# proven_oil_reserves                       138    138            Qatar    1
# proven_oil_reserves_value                 138     84                0   46
# available_manpower                        138    138            Qatar    1
# available_manpower_value                  138    138      3,70,10,559    1
# total_population                          138    138            Qatar    1
# total_population_value                    138    138        34,37,720    1
# total_square_land_area                    138    138            Qatar    1
# total_square_land_area_value              138    138         3,57,022    1
# total_coastline_coverage                  109    109            Qatar    1
# total_coastline_coverage_value            109    104              853    2
# total_waterway_coverage                   138    138            Qatar    1
# total_waterway_coverage_value             138     92                0   38
# total_border_coverage                     129    129            Qatar    1
# total_border_coverage_value               129    125            1,667    2

# %%
df[df.duplicated()]
# Out:
#     military_strength  military_strength_power_index aircraft_strength  \
# 139               NaN                            NaN               NaN
# 140               NaN                            NaN               NaN
# 141               NaN                            NaN               NaN
# 142               NaN                            NaN               NaN
# 143               NaN                            NaN               NaN
# 144               NaN                            NaN               NaN
# 145               NaN                            NaN               NaN
# 146               NaN                            NaN               NaN
# 147               NaN                            NaN               NaN
# 148               NaN                            NaN               NaN
# 149               NaN                            NaN               NaN
# 150               NaN                            NaN               NaN
# 151               NaN                            NaN               NaN
# 152               NaN                            NaN               NaN
# 153               NaN                            NaN               NaN
# 154               NaN                            NaN               NaN
# 155               NaN                            NaN               NaN
# 156               NaN                            NaN               NaN
# 157               NaN                            NaN               NaN
# 158               NaN                            NaN               NaN
# 159               NaN                            NaN               NaN
# 160               NaN                            NaN               NaN
# 161               NaN                            NaN               NaN
# 162               NaN                            NaN               NaN
# 163               NaN                            NaN               NaN
# 164               NaN                            NaN               NaN
#
#     aircraft_strength_value fighter/interceptor_strength  \
# 139                     NaN                          NaN
# 140                     NaN                          NaN
# 141                     NaN                          NaN
# 142                     NaN                          NaN
# 143                     NaN                          NaN
# 144                     NaN                          NaN
# 145                     NaN                          NaN
# 146                     NaN                          NaN
# 147                     NaN                          NaN
# 148                     NaN                          NaN
# 149                     NaN                          NaN
# 150                     NaN                          NaN
# 151                     NaN                          NaN
# 152                     NaN                          NaN
# 153                     NaN                          NaN
# 154                     NaN                          NaN
# 155                     NaN                          NaN
# 156                     NaN                          NaN
# 157                     NaN                          NaN
# 158                     NaN                          NaN
# 159                     NaN                          NaN
# 160                     NaN                          NaN
# 161                     NaN                          NaN
# 162                     NaN                          NaN
# 163                     NaN                          NaN
# 164                     NaN                          NaN
#
#     fighter/interceptor_strength_value attack_aircraft_strength  \
# 139                                NaN                      NaN
# 140                                NaN                      NaN
# 141                                NaN                      NaN
# 142                                NaN                      NaN
# 143                                NaN                      NaN
# 144                                NaN                      NaN
# 145                                NaN                      NaN
# 146                                NaN                      NaN
# 147                                NaN                      NaN
# 148                                NaN                      NaN
# 149                                NaN                      NaN
# 150                                NaN                      NaN
# 151                                NaN                      NaN
# 152                                NaN                      NaN
# 153                                NaN                      NaN
# 154                                NaN                      NaN
# 155                                NaN                      NaN
# 156                                NaN                      NaN
# 157                                NaN                      NaN
# 158                                NaN                      NaN
# 159                                NaN                      NaN
# 160                                NaN                      NaN
# 161                                NaN                      NaN
# 162                                NaN                      NaN
# 163                                NaN                      NaN
# 164                                NaN                      NaN
#
#      attack_aircraft_strength_value transport_aircraft_fleet_strength  \
# 139                             NaN                               NaN
# 140                             NaN                               NaN
# 141                             NaN                               NaN
# 142                             NaN                               NaN
# 143                             NaN                               NaN
# 144                             NaN                               NaN
# 145                             NaN                               NaN
# 146                             NaN                               NaN
# 147                             NaN                               NaN
# 148                             NaN                               NaN
# 149                             NaN                               NaN
# 150                             NaN                               NaN
# 151                             NaN                               NaN
# 152                             NaN                               NaN
# 153                             NaN                               NaN
# 154                             NaN                               NaN
# 155                             NaN                               NaN
# 156                             NaN                               NaN
# 157                             NaN                               NaN
# 158                             NaN                               NaN
# 159                             NaN                               NaN
# 160                             NaN                               NaN
# 161                             NaN                               NaN
# 162                             NaN                               NaN
# 163                             NaN                               NaN
# 164                             NaN                               NaN
#
#      transport_aircraft_fleet_strength_value trainer_aircraft_fleet  \
# 139                                      NaN                    NaN
# 140                                      NaN                    NaN
# 141                                      NaN                    NaN
# 142                                      NaN                    NaN
# 143                                      NaN                    NaN
# 144                                      NaN                    NaN
# 145                                      NaN                    NaN
# 146                                      NaN                    NaN
# 147                                      NaN                    NaN
# 148                                      NaN                    NaN
# 149                                      NaN                    NaN
# 150                                      NaN                    NaN
# 151                                      NaN                    NaN
# 152                                      NaN                    NaN
# 153                                      NaN                    NaN
# 154                                      NaN                    NaN
# 155                                      NaN                    NaN
# 156                                      NaN                    NaN
# 157                                      NaN                    NaN
# 158                                      NaN                    NaN
# 159                                      NaN                    NaN
# 160                                      NaN                    NaN
# 161                                      NaN                    NaN
# 162                                      NaN                    NaN
# 163                                      NaN                    NaN
# 164                                      NaN                    NaN
#
#     trainer_aircraft_fleet_value helicopter_fleet_strength  \
# 139                          NaN                       NaN
# 140                          NaN                       NaN
# 141                          NaN                       NaN
# 142                          NaN                       NaN
# 143                          NaN                       NaN
# 144                          NaN                       NaN
# 145                          NaN                       NaN
# 146                          NaN                       NaN
# 147                          NaN                       NaN
# 148                          NaN                       NaN
# 149                          NaN                       NaN
# 150                          NaN                       NaN
# 151                          NaN                       NaN
# 152                          NaN                       NaN
# 153                          NaN                       NaN
# 154                          NaN                       NaN
# 155                          NaN                       NaN
# 156                          NaN                       NaN
# 157                          NaN                       NaN
# 158                          NaN                       NaN
# 159                          NaN                       NaN
# 160                          NaN                       NaN
# 161                          NaN                       NaN
# 162                          NaN                       NaN
# 163                          NaN                       NaN
# 164                          NaN                       NaN
#
#     helicopter_fleet_strength_value attack_helicopter_fleet_strength  \
# 139                             NaN                              NaN
# 140                             NaN                              NaN
# 141                             NaN                              NaN
# 142                             NaN                              NaN
# 143                             NaN                              NaN
# 144                             NaN                              NaN
# 145                             NaN                              NaN
# 146                             NaN                              NaN
# 147                             NaN                              NaN
# 148                             NaN                              NaN
# 149                             NaN                              NaN
# 150                             NaN                              NaN
# 151                             NaN                              NaN
# 152                             NaN                              NaN
# 153                             NaN                              NaN
# 154                             NaN                              NaN
# 155                             NaN                              NaN
# 156                             NaN                              NaN
# 157                             NaN                              NaN
# 158                             NaN                              NaN
# 159                             NaN                              NaN
# 160                             NaN                              NaN
# 161                             NaN                              NaN
# 162                             NaN                              NaN
# 163                             NaN                              NaN
# 164                             NaN                              NaN
#
#      attack_helicopter_fleet_strength_value tank_strength tank_strength_value  \
# 139                                     NaN           NaN                 NaN
# 140                                     NaN           NaN                 NaN
# 141                                     NaN           NaN                 NaN
# 142                                     NaN           NaN                 NaN
# 143                                     NaN           NaN                 NaN
# 144                                     NaN           NaN                 NaN
# 145                                     NaN           NaN                 NaN
# 146                                     NaN           NaN                 NaN
# 147                                     NaN           NaN                 NaN
# 148                                     NaN           NaN                 NaN
# 149                                     NaN           NaN                 NaN
# 150                                     NaN           NaN                 NaN
# 151                                     NaN           NaN                 NaN
# 152                                     NaN           NaN                 NaN
# 153                                     NaN           NaN                 NaN
# 154                                     NaN           NaN                 NaN
# 155                                     NaN           NaN                 NaN
# 156                                     NaN           NaN                 NaN
# 157                                     NaN           NaN                 NaN
# 158                                     NaN           NaN                 NaN
# 159                                     NaN           NaN                 NaN
# 160                                     NaN           NaN                 NaN
# 161                                     NaN           NaN                 NaN
# 162                                     NaN           NaN                 NaN
# 163                                     NaN           NaN                 NaN
# 164                                     NaN           NaN                 NaN
#
#     afv/apc_strength afv/apc_strength_value self-propelled_artillery_strength  \
# 139              NaN                    NaN                               NaN
# 140              NaN                    NaN                               NaN
# 141              NaN                    NaN                               NaN
# 142              NaN                    NaN                               NaN
# 143              NaN                    NaN                               NaN
# 144              NaN                    NaN                               NaN
# 145              NaN                    NaN                               NaN
# 146              NaN                    NaN                               NaN
# 147              NaN                    NaN                               NaN
# 148              NaN                    NaN                               NaN
# 149              NaN                    NaN                               NaN
# 150              NaN                    NaN                               NaN
# 151              NaN                    NaN                               NaN
# 152              NaN                    NaN                               NaN
# 153              NaN                    NaN                               NaN
# 154              NaN                    NaN                               NaN
# 155              NaN                    NaN                               NaN
# 156              NaN                    NaN                               NaN
# 157              NaN                    NaN                               NaN
# 158              NaN                    NaN                               NaN
# 159              NaN                    NaN                               NaN
# 160              NaN                    NaN                               NaN
# 161              NaN                    NaN                               NaN
# 162              NaN                    NaN                               NaN
# 163              NaN                    NaN                               NaN
# 164              NaN                    NaN                               NaN
#
#     self-propelled_artillery_strength_value towed_artillery_strength  \
# 139                                     NaN                      NaN
# 140                                     NaN                      NaN
# 141                                     NaN                      NaN
# 142                                     NaN                      NaN
# 143                                     NaN                      NaN
# 144                                     NaN                      NaN
# 145                                     NaN                      NaN
# 146                                     NaN                      NaN
# 147                                     NaN                      NaN
# 148                                     NaN                      NaN
# 149                                     NaN                      NaN
# 150                                     NaN                      NaN
# 151                                     NaN                      NaN
# 152                                     NaN                      NaN
# 153                                     NaN                      NaN
# 154                                     NaN                      NaN
# 155                                     NaN                      NaN
# 156                                     NaN                      NaN
# 157                                     NaN                      NaN
# 158                                     NaN                      NaN
# 159                                     NaN                      NaN
# 160                                     NaN                      NaN
# 161                                     NaN                      NaN
# 162                                     NaN                      NaN
# 163                                     NaN                      NaN
# 164                                     NaN                      NaN
#
#     towed_artillery_strength_value rocket_projector_strength  \
# 139                            NaN                       NaN
# 140                            NaN                       NaN
# 141                            NaN                       NaN
# 142                            NaN                       NaN
# 143                            NaN                       NaN
# 144                            NaN                       NaN
# 145                            NaN                       NaN
# 146                            NaN                       NaN
# 147                            NaN                       NaN
# 148                            NaN                       NaN
# 149                            NaN                       NaN
# 150                            NaN                       NaN
# 151                            NaN                       NaN
# 152                            NaN                       NaN
# 153                            NaN                       NaN
# 154                            NaN                       NaN
# 155                            NaN                       NaN
# 156                            NaN                       NaN
# 157                            NaN                       NaN
# 158                            NaN                       NaN
# 159                            NaN                       NaN
# 160                            NaN                       NaN
# 161                            NaN                       NaN
# 162                            NaN                       NaN
# 163                            NaN                       NaN
# 164                            NaN                       NaN
#
#     rocket_projector_strength_value navy_fleet_strengths  \
# 139                             NaN                  NaN
# 140                             NaN                  NaN
# 141                             NaN                  NaN
# 142                             NaN                  NaN
# 143                             NaN                  NaN
# 144                             NaN                  NaN
# 145                             NaN                  NaN
# 146                             NaN                  NaN
# 147                             NaN                  NaN
# 148                             NaN                  NaN
# 149                             NaN                  NaN
# 150                             NaN                  NaN
# 151                             NaN                  NaN
# 152                             NaN                  NaN
# 153                             NaN                  NaN
# 154                             NaN                  NaN
# 155                             NaN                  NaN
# 156                             NaN                  NaN
# 157                             NaN                  NaN
# 158                             NaN                  NaN
# 159                             NaN                  NaN
# 160                             NaN                  NaN
# 161                             NaN                  NaN
# 162                             NaN                  NaN
# 163                             NaN                  NaN
# 164                             NaN                  NaN
#
#      navy_fleet_strengths_value aircraft_carrier_fleet_strength  \
# 139                         NaN                             NaN
# 140                         NaN                             NaN
# 141                         NaN                             NaN
# 142                         NaN                             NaN
# 143                         NaN                             NaN
# 144                         NaN                             NaN
# 145                         NaN                             NaN
# 146                         NaN                             NaN
# 147                         NaN                             NaN
# 148                         NaN                             NaN
# 149                         NaN                             NaN
# 150                         NaN                             NaN
# 151                         NaN                             NaN
# 152                         NaN                             NaN
# 153                         NaN                             NaN
# 154                         NaN                             NaN
# 155                         NaN                             NaN
# 156                         NaN                             NaN
# 157                         NaN                             NaN
# 158                         NaN                             NaN
# 159                         NaN                             NaN
# 160                         NaN                             NaN
# 161                         NaN                             NaN
# 162                         NaN                             NaN
# 163                         NaN                             NaN
# 164                         NaN                             NaN
#
#      aircraft_carrier_fleet_strength_value submarine_fleet_strength  \
# 139                                    NaN                      NaN
# 140                                    NaN                      NaN
# 141                                    NaN                      NaN
# 142                                    NaN                      NaN
# 143                                    NaN                      NaN
# 144                                    NaN                      NaN
# 145                                    NaN                      NaN
# 146                                    NaN                      NaN
# 147                                    NaN                      NaN
# 148                                    NaN                      NaN
# 149                                    NaN                      NaN
# 150                                    NaN                      NaN
# 151                                    NaN                      NaN
# 152                                    NaN                      NaN
# 153                                    NaN                      NaN
# 154                                    NaN                      NaN
# 155                                    NaN                      NaN
# 156                                    NaN                      NaN
# 157                                    NaN                      NaN
# 158                                    NaN                      NaN
# 159                                    NaN                      NaN
# 160                                    NaN                      NaN
# 161                                    NaN                      NaN
# 162                                    NaN                      NaN
# 163                                    NaN                      NaN
# 164                                    NaN                      NaN
#
#      submarine_fleet_strength_value destroyer_fleet_strength  \
# 139                             NaN                      NaN
# 140                             NaN                      NaN
# 141                             NaN                      NaN
# 142                             NaN                      NaN
# 143                             NaN                      NaN
# 144                             NaN                      NaN
# 145                             NaN                      NaN
# 146                             NaN                      NaN
# 147                             NaN                      NaN
# 148                             NaN                      NaN
# 149                             NaN                      NaN
# 150                             NaN                      NaN
# 151                             NaN                      NaN
# 152                             NaN                      NaN
# 153                             NaN                      NaN
# 154                             NaN                      NaN
# 155                             NaN                      NaN
# 156                             NaN                      NaN
# 157                             NaN                      NaN
# 158                             NaN                      NaN
# 159                             NaN                      NaN
# 160                             NaN                      NaN
# 161                             NaN                      NaN
# 162                             NaN                      NaN
# 163                             NaN                      NaN
# 164                             NaN                      NaN
#
#      destroyer_fleet_strength_value frigate_fleet_strength  \
# 139                             NaN                    NaN
# 140                             NaN                    NaN
# 141                             NaN                    NaN
# 142                             NaN                    NaN
# 143                             NaN                    NaN
# 144                             NaN                    NaN
# 145                             NaN                    NaN
# 146                             NaN                    NaN
# 147                             NaN                    NaN
# 148                             NaN                    NaN
# 149                             NaN                    NaN
# 150                             NaN                    NaN
# 151                             NaN                    NaN
# 152                             NaN                    NaN
# 153                             NaN                    NaN
# 154                             NaN                    NaN
# 155                             NaN                    NaN
# 156                             NaN                    NaN
# 157                             NaN                    NaN
# 158                             NaN                    NaN
# 159                             NaN                    NaN
# 160                             NaN                    NaN
# 161                             NaN                    NaN
# 162                             NaN                    NaN
# 163                             NaN                    NaN
# 164                             NaN                    NaN
#
#      frigate_fleet_strength_value defense_spending_budget  \
# 139                           NaN                     NaN
# 140                           NaN                     NaN
# 141                           NaN                     NaN
# 142                           NaN                     NaN
# 143                           NaN                     NaN
# 144                           NaN                     NaN
# 145                           NaN                     NaN
# 146                           NaN                     NaN
# 147                           NaN                     NaN
# 148                           NaN                     NaN
# 149                           NaN                     NaN
# 150                           NaN                     NaN
# 151                           NaN                     NaN
# 152                           NaN                     NaN
# 153                           NaN                     NaN
# 154                           NaN                     NaN
# 155                           NaN                     NaN
# 156                           NaN                     NaN
# 157                           NaN                     NaN
# 158                           NaN                     NaN
# 159                           NaN                     NaN
# 160                           NaN                     NaN
# 161                           NaN                     NaN
# 162                           NaN                     NaN
# 163                           NaN                     NaN
# 164                           NaN                     NaN
#
#     defense_spending_budget_value external_debt external_debt_value  \
# 139                           NaN           NaN                 NaN
# 140                           NaN           NaN                 NaN
# 141                           NaN           NaN                 NaN
# 142                           NaN           NaN                 NaN
# 143                           NaN           NaN                 NaN
# 144                           NaN           NaN                 NaN
# 145                           NaN           NaN                 NaN
# 146                           NaN           NaN                 NaN
# 147                           NaN           NaN                 NaN
# 148                           NaN           NaN                 NaN
# 149                           NaN           NaN                 NaN
# 150                           NaN           NaN                 NaN
# 151                           NaN           NaN                 NaN
# 152                           NaN           NaN                 NaN
# 153                           NaN           NaN                 NaN
# 154                           NaN           NaN                 NaN
# 155                           NaN           NaN                 NaN
# 156                           NaN           NaN                 NaN
# 157                           NaN           NaN                 NaN
# 158                           NaN           NaN                 NaN
# 159                           NaN           NaN                 NaN
# 160                           NaN           NaN                 NaN
# 161                           NaN           NaN                 NaN
# 162                           NaN           NaN                 NaN
# 163                           NaN           NaN                 NaN
# 164                           NaN           NaN                 NaN
#
#     airport_totals airport_totals_value oil_production oil_production_value  \
# 139            NaN                  NaN            NaN                  NaN
# 140            NaN                  NaN            NaN                  NaN
# 141            NaN                  NaN            NaN                  NaN
# 142            NaN                  NaN            NaN                  NaN
# 143            NaN                  NaN            NaN                  NaN
# 144            NaN                  NaN            NaN                  NaN
# 145            NaN                  NaN            NaN                  NaN
# 146            NaN                  NaN            NaN                  NaN
# 147            NaN                  NaN            NaN                  NaN
# 148            NaN                  NaN            NaN                  NaN
# 149            NaN                  NaN            NaN                  NaN
# 150            NaN                  NaN            NaN                  NaN
# 151            NaN                  NaN            NaN                  NaN
# 152            NaN                  NaN            NaN                  NaN
# 153            NaN                  NaN            NaN                  NaN
# 154            NaN                  NaN            NaN                  NaN
# 155            NaN                  NaN            NaN                  NaN
# 156            NaN                  NaN            NaN                  NaN
# 157            NaN                  NaN            NaN                  NaN
# 158            NaN                  NaN            NaN                  NaN
# 159            NaN                  NaN            NaN                  NaN
# 160            NaN                  NaN            NaN                  NaN
# 161            NaN                  NaN            NaN                  NaN
# 162            NaN                  NaN            NaN                  NaN
# 163            NaN                  NaN            NaN                  NaN
# 164            NaN                  NaN            NaN                  NaN
#
#     oil_consumption oil_consumption_value proven_oil_reserves  \
# 139             NaN                   NaN                 NaN
# 140             NaN                   NaN                 NaN
# 141             NaN                   NaN                 NaN
# 142             NaN                   NaN                 NaN
# 143             NaN                   NaN                 NaN
# 144             NaN                   NaN                 NaN
# 145             NaN                   NaN                 NaN
# 146             NaN                   NaN                 NaN
# 147             NaN                   NaN                 NaN
# 148             NaN                   NaN                 NaN
# 149             NaN                   NaN                 NaN
# 150             NaN                   NaN                 NaN
# 151             NaN                   NaN                 NaN
# 152             NaN                   NaN                 NaN
# 153             NaN                   NaN                 NaN
# 154             NaN                   NaN                 NaN
# 155             NaN                   NaN                 NaN
# 156             NaN                   NaN                 NaN
# 157             NaN                   NaN                 NaN
# 158             NaN                   NaN                 NaN
# 159             NaN                   NaN                 NaN
# 160             NaN                   NaN                 NaN
# 161             NaN                   NaN                 NaN
# 162             NaN                   NaN                 NaN
# 163             NaN                   NaN                 NaN
# 164             NaN                   NaN                 NaN
#
#     proven_oil_reserves_value available_manpower available_manpower_value  \
# 139                       NaN                NaN                      NaN
# 140                       NaN                NaN                      NaN
# 141                       NaN                NaN                      NaN
# 142                       NaN                NaN                      NaN
# 143                       NaN                NaN                      NaN
# 144                       NaN                NaN                      NaN
# 145                       NaN                NaN                      NaN
# 146                       NaN                NaN                      NaN
# 147                       NaN                NaN                      NaN
# 148                       NaN                NaN                      NaN
# 149                       NaN                NaN                      NaN
# 150                       NaN                NaN                      NaN
# 151                       NaN                NaN                      NaN
# 152                       NaN                NaN                      NaN
# 153                       NaN                NaN                      NaN
# 154                       NaN                NaN                      NaN
# 155                       NaN                NaN                      NaN
# 156                       NaN                NaN                      NaN
# 157                       NaN                NaN                      NaN
# 158                       NaN                NaN                      NaN
# 159                       NaN                NaN                      NaN
# 160                       NaN                NaN                      NaN
# 161                       NaN                NaN                      NaN
# 162                       NaN                NaN                      NaN
# 163                       NaN                NaN                      NaN
# 164                       NaN                NaN                      NaN
#
#     total_population total_population_value total_square_land_area  \
# 139              NaN                    NaN                    NaN
# 140              NaN                    NaN                    NaN
# 141              NaN                    NaN                    NaN
# 142              NaN                    NaN                    NaN
# 143              NaN                    NaN                    NaN
# 144              NaN                    NaN                    NaN
# 145              NaN                    NaN                    NaN
# 146              NaN                    NaN                    NaN
# 147              NaN                    NaN                    NaN
# 148              NaN                    NaN                    NaN
# 149              NaN                    NaN                    NaN
# 150              NaN                    NaN                    NaN
# 151              NaN                    NaN                    NaN
# 152              NaN                    NaN                    NaN
# 153              NaN                    NaN                    NaN
# 154              NaN                    NaN                    NaN
# 155              NaN                    NaN                    NaN
# 156              NaN                    NaN                    NaN
# 157              NaN                    NaN                    NaN
# 158              NaN                    NaN                    NaN
# 159              NaN                    NaN                    NaN
# 160              NaN                    NaN                    NaN
# 161              NaN                    NaN                    NaN
# 162              NaN                    NaN                    NaN
# 163              NaN                    NaN                    NaN
# 164              NaN                    NaN                    NaN
#
#     total_square_land_area_value total_coastline_coverage  \
# 139                          NaN                      NaN
# 140                          NaN                      NaN
# 141                          NaN                      NaN
# 142                          NaN                      NaN
# 143                          NaN                      NaN
# 144                          NaN                      NaN
# 145                          NaN                      NaN
# 146                          NaN                      NaN
# 147                          NaN                      NaN
# 148                          NaN                      NaN
# 149                          NaN                      NaN
# 150                          NaN                      NaN
# 151                          NaN                      NaN
# 152                          NaN                      NaN
# 153                          NaN                      NaN
# 154                          NaN                      NaN
# 155                          NaN                      NaN
# 156                          NaN                      NaN
# 157                          NaN                      NaN
# 158                          NaN                      NaN
# 159                          NaN                      NaN
# 160                          NaN                      NaN
# 161                          NaN                      NaN
# 162                          NaN                      NaN
# 163                          NaN                      NaN
# 164                          NaN                      NaN
#
#     total_coastline_coverage_value total_waterway_coverage  \
# 139                            NaN                     NaN
# 140                            NaN                     NaN
# 141                            NaN                     NaN
# 142                            NaN                     NaN
# 143                            NaN                     NaN
# 144                            NaN                     NaN
# 145                            NaN                     NaN
# 146                            NaN                     NaN
# 147                            NaN                     NaN
# 148                            NaN                     NaN
# 149                            NaN                     NaN
# 150                            NaN                     NaN
# 151                            NaN                     NaN
# 152                            NaN                     NaN
# 153                            NaN                     NaN
# 154                            NaN                     NaN
# 155                            NaN                     NaN
# 156                            NaN                     NaN
# 157                            NaN                     NaN
# 158                            NaN                     NaN
# 159                            NaN                     NaN
# 160                            NaN                     NaN
# 161                            NaN                     NaN
# 162                            NaN                     NaN
# 163                            NaN                     NaN
# 164                            NaN                     NaN
#
#     total_waterway_coverage_value total_border_coverage  \
# 139                           NaN                   NaN
# 140                           NaN                   NaN
# 141                           NaN                   NaN
# 142                           NaN                   NaN
# 143                           NaN                   NaN
# 144                           NaN                   NaN
# 145                           NaN                   NaN
# 146                           NaN                   NaN
# 147                           NaN                   NaN
# 148                           NaN                   NaN
# 149                           NaN                   NaN
# 150                           NaN                   NaN
# 151                           NaN                   NaN
# 152                           NaN                   NaN
# 153                           NaN                   NaN
# 154                           NaN                   NaN
# 155                           NaN                   NaN
# 156                           NaN                   NaN
# 157                           NaN                   NaN
# 158                           NaN                   NaN
# 159                           NaN                   NaN
# 160                           NaN                   NaN
# 161                           NaN                   NaN
# 162                           NaN                   NaN
# 163                           NaN                   NaN
# 164                           NaN                   NaN
#
#     total_border_coverage_value
# 139                         NaN
# 140                         NaN
# 141                         NaN
# 142                         NaN
# 143                         NaN
# 144                         NaN
# 145                         NaN
# 146                         NaN
# 147                         NaN
# 148                         NaN
# 149                         NaN
# 150                         NaN
# 151                         NaN
# 152                         NaN
# 153                         NaN
# 154                         NaN
# 155                         NaN
# 156                         NaN
# 157                         NaN
# 158                         NaN
# 159                         NaN
# 160                         NaN
# 161                         NaN
# 162                         NaN
# 163                         NaN
# 164                         NaN

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
df.shape
# Out:
# (138, 60)

# %%
df.head(1)
# Out:
#   military_strength  military_strength_power_index aircraft_strength  \
# 0       Afghanistan                          1.344       Afghanistan
#
#   aircraft_strength_value fighter/interceptor_strength  \
# 0                     260                  Afghanistan
#
#   fighter/interceptor_strength_value attack_aircraft_strength  \
# 0                                  0              Afghanistan
#
#    attack_aircraft_strength_value transport_aircraft_fleet_strength  \
# 0                          25.000                       Afghanistan
#
#    transport_aircraft_fleet_strength_value trainer_aircraft_fleet  \
# 0                                   30.000            Afghanistan
#
#   trainer_aircraft_fleet_value helicopter_fleet_strength  \
# 0                            0               Afghanistan
#
#   helicopter_fleet_strength_value attack_helicopter_fleet_strength  \
# 0                             187                      Afghanistan
#
#    attack_helicopter_fleet_strength_value tank_strength tank_strength_value  \
# 0                                   0.000   Afghanistan                   0
#
#   afv/apc_strength afv/apc_strength_value self-propelled_artillery_strength  \
# 0      Afghanistan                  1,062                       Afghanistan
#
#   self-propelled_artillery_strength_value towed_artillery_strength  \
# 0                                       0              Afghanistan
#
#   towed_artillery_strength_value rocket_projector_strength  \
# 0                            176               Afghanistan
#
#   rocket_projector_strength_value navy_fleet_strengths  \
# 0                              50          Afghanistan
#
#    navy_fleet_strengths_value aircraft_carrier_fleet_strength  \
# 0                       0.000                     Afghanistan
#
#    aircraft_carrier_fleet_strength_value submarine_fleet_strength  \
# 0                                  0.000              Afghanistan
#
#    submarine_fleet_strength_value destroyer_fleet_strength  \
# 0                           0.000              Afghanistan
#
#    destroyer_fleet_strength_value frigate_fleet_strength  \
# 0                           0.000            Afghanistan
#
#    frigate_fleet_strength_value defense_spending_budget  \
# 0                         0.000             Afghanistan
#
#   defense_spending_budget_value external_debt external_debt_value  \
# 0               12,00,00,00,000   Afghanistan      2,84,00,00,000
#
#   airport_totals airport_totals_value oil_production oil_production_value  \
# 0    Afghanistan                   43    Afghanistan                    0
#
#   oil_consumption oil_consumption_value proven_oil_reserves  \
# 0     Afghanistan                 5,500         Afghanistan
#
#   proven_oil_reserves_value available_manpower available_manpower_value  \
# 0                         0        Afghanistan              1,43,25,743
#
#   total_population total_population_value total_square_land_area  \
# 0      Afghanistan            3,49,40,837            Afghanistan
#
#   total_square_land_area_value total_coastline_coverage  \
# 0                     6,52,230              Afghanistan
#
#   total_coastline_coverage_value total_waterway_coverage  \
# 0                              0             Afghanistan
#
#   total_waterway_coverage_value total_border_coverage  \
# 0                         1,200           Afghanistan
#
#   total_border_coverage_value
# 0                       5,987

# %%
df.rename(columns={'military_strength': 'country'}, inplace=True)

# %%
value_cols = [i[0] for i in df.columns.str.findall(".*value") if i !=[]]

value_cols
# Out:
# ['aircraft_strength_value',
#  'fighter/interceptor_strength_value',
#  'attack_aircraft_strength_value',
#  'transport_aircraft_fleet_strength_value',
#  'trainer_aircraft_fleet_value',
#  'helicopter_fleet_strength_value',
#  'attack_helicopter_fleet_strength_value',
#  'tank_strength_value',
#  'afv/apc_strength_value',
#  'self-propelled_artillery_strength_value',
#  'towed_artillery_strength_value',
#  'rocket_projector_strength_value',
#  'navy_fleet_strengths_value',
#  'aircraft_carrier_fleet_strength_value',
#  'submarine_fleet_strength_value',
#  'destroyer_fleet_strength_value',
#  'frigate_fleet_strength_value',
#  'defense_spending_budget_value',
#  'external_debt_value',
#  'airport_totals_value',
#  'oil_production_value',
#  'oil_consumption_value',
#  'proven_oil_reserves_value',
#  'available_manpower_value',
#  'total_population_value',
#  'total_square_land_area_value',
#  'total_coastline_coverage_value',
#  'total_waterway_coverage_value',
#  'total_border_coverage_value']
